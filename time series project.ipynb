# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path= r'C:\Users\DEVIL MAY CRY\Desktop\learning\python projects\time series udemy\individual_stocks_5yr'
company_list = ['AAPL_data.csv', 'GOOG_data.csv', 'MSFT_data.csv', 'AMZN_data.csv']

#blank dataframe
all_data = pd.DataFrame()

for file in company_list:
    current_df = pd.read_csv(path+"/"+file)
    all_data = pd.concat([all_data, current_df])
    
all_data.shape
# Out:
# (4752, 7)

# %%
all_data.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %% [markdown]
# # 1) Analyzing the closing price of all the stocks over a given period of time to identify trends and patterns in the market.

# %%
tech_list = all_data['Name'].unique()

# %%
all_data.dtypes
# Out:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# Name       object
# dtype: object

# %%
all_data['date'] = pd.to_datetime(all_data['date'])

# %%
plt.figure(figsize = (20,12))
for i, company in enumerate(tech_list,1):
    plt.subplot(2,2,i)
    df = all_data[all_data['Name']== company]
    plt.plot(df['date'],df['close'])
    plt.title(company)

# %% [markdown]
# # 2) Examining the total volume of stock being traded each day to determine market liquidity and demand for particular stocks.

# %%
import plotly.express as px

# %%
for company in tech_list:
    df = all_data[all_data['Name']== company]
    fig =   px.line(df,x='date' , y = 'volume' , title = company)
    fig.show()
# Out:
# <div>                            <div id="b270add6-8059-4163-b48d-bc10c74ad575" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b270add6-8059-4163-b48d-bc10c74ad575")) {                    Plotly.newPlot(                        "b270add6-8059-4163-b48d-bc10c74ad575",                        [{"hovertemplate":"date=%{x}<br>volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-0
# ...

# %% [markdown]
# # 3) Analyzing daily price changes in stocks to identify volatility and risk associated with specific investments.

# %%
df1 =  pd.read_csv(r'C:\Users\DEVIL MAY CRY\Desktop\learning\python projects\time series udemy\individual_stocks_5yr/AAPL_data.csv')

# %%
df1.head(20)
# Out:
#           date     open     high      low    close     volume  Name
# 0   2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1   2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2   2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3   2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4   2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
# 5   2013-02-15  66.9785  67.1656  65.7028  65.7371   97924631  AAPL
# 6   2013-02-19  65.8714  66.1042  64.8356  65.7128  108854046  AAPL
# 7   2013-02-20  65.3842  65.3842  64.1142  64.1214  118891367  AAPL
# 8   2013-02-21  63.7142  64.1671  63.2599  63.7228  111596821  AAPL
# 9   2013-02-22  64.1785  64.5142  63.7999  64.4014   82583823  AAPL
# 10  2013-02-25  64.8356  65.0171  63.2242  63.2571   92899597  AAPL
# 11  2013-02-26  63.4028  64.5056  62.5228  64.1385  125096657  AAPL
# 12  2013-02-27  64.0614  64.6342  62.9499  63.5099  146674682  AAPL
# ...

# %%
df1['Daily_Price_change'] = df1['close'] - df1['open']
df1.head()
# Out:
#          date     open     high      low    close     volume  Name  \
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
#
#    Daily_Price_change
# 0              0.1400
# 1              0.4900
# 2             -1.6586
# 3             -0.0286
# 4              0.2957

# %%
df1['Daily percentage change'] = (df1['close'] - df1['open'])/df1['close']*100

# %%
df1.head()
# Out:
#          date     open     high      low    close     volume  Name  \
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
#
#    Daily_Price_change  Daily percentage change
# 0              0.1400                 0.206325
# 1              0.4900                 0.714688
# 2             -1.6586                -2.481344
# 3             -0.0286                -0.042869
# 4              0.2957                 0.443624

# %%
fig =   px.line(df1,x='date' , y = 'Daily percentage change' , title = company)
fig.show()
# Out:
# <div>                            <div id="4b358d24-51d1-4af5-9a93-d2f682c59c77" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b358d24-51d1-4af5-9a93-d2f682c59c77")) {                    Plotly.newPlot(                        "4b358d24-51d1-4af5-9a93-d2f682c59c77",                        [{"hovertemplate":"date=%{x}<br>Daily percentage change=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-02-08","2013-02-11","2013-02-12","2013-02-13","2013-02-14","2013-02-15","2013-02-19","2013-02-20","2013-02-21","2013-02-22","2013-02-25","2013-02-26","2013-02-27","2013-02-28","2013-03-01","2013-03-04","2013-03-05","2013-03-06","2013-03-07","2013-0
# ...

# %% [markdown]
# #  4) Calculating monthly means of closing prices for a more long-term view of stock performance.

# %%
df2 = df1.copy()

# %%
df2.dtypes
# Out:
# date                        object
# open                       float64
# high                       float64
# low                        float64
# close                      float64
# volume                       int64
# Name                        object
# Daily_Price_change         float64
# Daily percentage change    float64
# dtype: object

# %%
df2['date'] = pd.to_datetime(df2['date'])

# %%
df2.set_index('date' , inplace = True)

# %%
df2.head()
# Out:
#                open     high      low    close     volume  Name  \
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
#
#             Daily_Price_change  Daily percentage change
# date
# 2013-02-08              0.1400                 0.206325
# 2013-02-11              0.4900                 0.714688
# 2013-02-12             -1.6586                -2.481344
# 2013-02-13             -0.0286                -0.042869
# 2013-02-14              0.2957                 0.443624

# %%
df2['2013-02-08 ' : '2013-02-14']
# Out:
#                open     high      low    close     volume  Name  \
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
#
#             Daily_Price_change  Daily percentage change
# date
# 2013-02-08              0.1400                 0.206325
# 2013-02-11              0.4900                 0.714688
# 2013-02-12             -1.6586                -2.481344
# 2013-02-13             -0.0286                -0.042869
# 2013-02-14              0.2957                 0.443624

# %%
df2['close'].resample('M').mean()
# Out:
# date
# 2013-02-28     65.306264
# 2013-03-31     63.120110
# 2013-04-30     59.966432
# 2013-05-31     63.778927
# 2013-06-30     60.791120
#                  ...
# 2017-10-31    157.817273
# 2017-11-30    172.406190
# 2017-12-31    171.891500
# 2018-01-31    174.005238
# 2018-02-28    161.468000
# Freq: M, Name: close, Length: 61, dtype: float64

# %%
df2['close'].resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df2['close'].resample('Y').mean().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# # 5) Checking if the stock prices of major tech companies such as Amazon, Apple, Google, and Microsoft are correlated or not, which can provide insights into market trends and sector performance.

# %%
 apple = pd.read_csv(r'C:\Users\DEVIL MAY CRY\Desktop\learning\python projects\time series udemy\individual_stocks_5yr/AAPL_data.csv')
 apple.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
amazon = microsoft = pd.read_csv(r'C:\Users\DEVIL MAY CRY\Desktop\learning\python projects\time series udemy\individual_stocks_5yr/AMZN_data.csv')
amazon.head()
# Out:
#          date    open    high      low   close   volume  Name
# 0  2013-02-08  261.40  265.25  260.555  261.95  3879078  AMZN
# 1  2013-02-11  263.20  263.25  256.600  257.21  3403403  AMZN
# 2  2013-02-12  259.19  260.16  257.000  258.70  2938660  AMZN
# 3  2013-02-13  261.53  269.96  260.300  269.47  5292996  AMZN
# 4  2013-02-14  267.37  270.65  265.400  269.24  3462780  AMZN

# %%
microsoft = pd.read_csv(r'C:\Users\DEVIL MAY CRY\Desktop\learning\python projects\time series udemy\individual_stocks_5yr/MSFT_data.csv')
microsoft.head()
# Out:
#          date   open   high    low  close    volume  Name
# 0  2013-02-08  27.35  27.71  27.31  27.55  33318306  MSFT
# 1  2013-02-11  27.65  27.92  27.50  27.86  32247549  MSFT
# 2  2013-02-12  27.88  28.00  27.75  27.88  35990829  MSFT
# 3  2013-02-13  27.93  28.11  27.88  28.03  41715530  MSFT
# 4  2013-02-14  27.92  28.06  27.87  28.04  32663174  MSFT

# %%
google = pd.read_csv(r'C:\Users\DEVIL MAY CRY\Desktop\learning\python projects\time series udemy\individual_stocks_5yr/GOOG_data.csv')
google.head()
# Out:
#          date     open    high     low   close  volume  Name
# 0  2014-03-27  568.000  568.00  552.92  558.46   13052  GOOG
# 1  2014-03-28  561.200  566.43  558.67  559.99   41003  GOOG
# 2  2014-03-31  566.890  567.00  556.93  556.97   10772  GOOG
# 3  2014-04-01  558.710  568.45  558.71  567.16    7932  GOOG
# 4  2014-04-02  565.106  604.83  562.19  567.00  146697  GOOG

# %%
close = pd.DataFrame()

# %%
close['apple'] = apple['close']
close['google'] = google['close']
close['amazon'] = amazon['close']
close['microsoft'] = microsoft['close']

# %%
close.head()
# Out:
#      apple  google  amazon  microsoft
# 0  67.8542  558.46  261.95      27.55
# 1  68.5614  559.99  257.21      27.86
# 2  66.8428  556.97  258.70      27.88
# 3  66.7156  567.16  269.47      28.03
# 4  66.6556  567.00  269.24      28.04

# %%
sns.pairplot(data = close)

# %%
sns.heatmap(close.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
# amazon and microsofthave highest collinearity

# %% [markdown]
# # 6) Analyzing the daily return of each stock and identifying how they are co-related to gain a better understanding of investment opportunities and risks.

# %%
apple.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
data = pd.DataFrame()

# %%
data['apple_change'] = ((apple['close']-apple['open'])/apple['close'])*100
data['google_change'] = ((google['close']-google['open'])/google['close'])*100
data['microsoft_change'] = ((microsoft['close']-microsoft['open'])/microsoft['close'])*100
data['amazon_change'] = ((amazon['close']-amazon['open'])/amazon['close'])*100

# %%
data.head()
# Out:
#    apple_change  google_change  microsoft_change  amazon_change
# 0      0.206325      -1.708269          0.725953       0.209964
# 1      0.714688      -0.216075          0.753769      -2.328836
# 2     -2.481344      -1.781065          0.000000      -0.189409
# 3     -0.042869       1.489879          0.356761       2.946525
# 4      0.443624       0.334039          0.427960       0.694548

# %%
sns.pairplot(data=data)

# %%
sns.heatmap(data.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 7) value at Risk analysis for tech companies

# %%
sns.distplot(data['apple_change'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='apple_change', ylabel='Density'>

# %%
data['apple_change'].std()

# 68% of entire data
# Out:
# 1.1871377131421237

# %%
data['apple_change'].std()*2

## 95% of entire data
# Out:
# 2.3742754262842474

# %%
data['apple_change'].std()*3

### 99.7% of entire data
# Out:
# 3.561413139426371

# %%
data['apple_change'].quantile(0.1)

# it means 90% of the time worst daily loss will not excede 1.42%
# Out:
# -1.4246644227944307

# %%
data.describe()
# Out:
#        apple_change  google_change  microsoft_change  amazon_change
# count   1259.000000     975.000000       1259.000000    1259.000000
# mean      -0.000215      -0.012495          0.076404      -0.000398
# std        1.187138       1.092560          1.059260       1.358679
# min       -7.104299      -5.952266         -5.177618      -9.363077
# 25%       -0.658021      -0.551963         -0.509241      -0.738341
# 50%        0.042230       0.024951          0.061069      -0.002623
# 75%        0.715427       0.672649          0.703264       0.852568
# max        8.000388       4.943550          4.861491       5.640265

# %%
data.describe().T
# Out:
#                    count      mean       std       min       25%       50%  \
# apple_change      1259.0 -0.000215  1.187138 -7.104299 -0.658021  0.042230
# google_change      975.0 -0.012495  1.092560 -5.952266 -0.551963  0.024951
# microsoft_change  1259.0  0.076404  1.059260 -5.177618 -0.509241  0.061069
# amazon_change     1259.0 -0.000398  1.358679 -9.363077 -0.738341 -0.002623
#
#                        75%       max
# apple_change      0.715427  8.000388
# google_change     0.672649  4.943550
# microsoft_change  0.703264  4.861491
# amazon_change     0.852568  5.640265
